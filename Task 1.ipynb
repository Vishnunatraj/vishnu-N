# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishnunatraj/vishnu-N/blob/main/Task%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
y = [25, 28, 27, 30, 29, 31, 33]        # Actual temperature
pred = [26, 27, 28, 29, 30, 32, 34]     # Predicted temperature

# %%
X = df[["humidity", "pressure", "wind_speed"]]
y = df["temperature"]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
pred = model.predict(X)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df)
plt.suptitle("Pair Plot of Weather Dataset", y=1.02)
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse  = mean_squared_error(y, pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y, pred)

print("MSE :", mse)
print("RMSE:", rmse)
print("MAE :", mae)
# Out:
# MSE : 1.0
# RMSE: 1.0
# MAE : 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

index = np.arange(len(y))

plt.figure(figsize=(10,4))
plt.plot(index, y,   "bo-", alpha=0.5, label="Actual")
plt.plot(index, pred,"rs-", alpha=0.5, label="Predicted")
plt.xlabel("Sample Index")
plt.ylabel("Temperature (°C)")
plt.title("Actual vs Predicted Temperature")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()
plt.show()
